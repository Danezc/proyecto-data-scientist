# %% [markdown]
# # Guia de ejecucion del pipeline TumiPayEste notebook queda como indice. Para ejecutar procesos, usa los notebooks separados:1. `00_carga_base_supabase.ipynb`: carga limpia de `data/raw` a tablas `raw_*` en Supabase.2. `01_powerbi_predicciones.ipynb`: entrenamiento y carga de `predicciones_riesgo` para Power BI.3. `02_aporte_adicional_rag_llm.ipynb`: aporte adicional RAG + LLM para consultas en lenguaje natural.

# %%
from pathlib import Pathfor notebook in [    '00_carga_base_supabase.ipynb',    '01_powerbi_predicciones.ipynb',    '02_aporte_adicional_rag_llm.ipynb',]:    path = Path(notebook)    print(f'{notebook}: {'existe' if path.exists() else 'no encontrado'}')
